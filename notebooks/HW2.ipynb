# %%
import numpy as np
import pandas as pd
from sklearn.decomposition import PCA

# %%
FILE = '../data/Sample_Data.xlsx'
df = pd.read_excel(FILE)

# %%
df.head()
# Out:
#          X1        X2        X3        X4        X5        X6        X7  \
# 0 -0.178266 -1.232736 -0.755075 -0.025294 -0.935513 -2.612791 -0.453477
# 1 -0.122282  1.082396  1.453829 -1.212121 -0.312355  1.908761  1.456450
# 2 -0.145936  2.110116  2.042481 -0.841299  0.444485  0.976353  1.874961
# 3  1.789767  1.045230  1.472639  0.517910 -0.422547  2.162058  1.524488
# 4 -0.433913 -0.917178  0.329103  0.369805 -1.812501 -0.581058  0.667508
#
#          X8        X9       X10 Label      Y
# 0 -0.064638  0.705880  0.478928   PS4 -32.65
# 1  0.226062 -0.299493  0.519629   PS4  13.11
# 2  0.854823  0.387552  0.011759   PS4  28.92
# 3  0.375040  0.741500  0.567033   PS4  21.03
# 4  1.207047 -1.817363  1.533617   PS4 -19.30

# %%
pca_df = PCA(n_components=2).fit(df)
